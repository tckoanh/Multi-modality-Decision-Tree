# %% [markdown]
# # Building a Decision Tree

# %% [markdown]
# With JupyterBook it is possible to make your narrative and data-analysis available in a single file, through Jupyter Notebooks. It is even possible to create interactive materials using widgets on the website, but leave them out in the PDF version (using tags). To run the code below, click the ![](figures/on.png) icon in the top right corner. This will connect with a kernel. If the kernel is loaded, click ![](figures/play.png) to run the code.

# %% [markdown]
# <iframe src="decision_tree_simulator.html" width="900" height="500"></iframe>

# %%
from IPython.display import HTML

with open("decision_tree_simulator.html", "r", encoding="utf-8") as f:
    html_content = f.read()

HTML(html_content)
# Out:
# Running cells with 'research_project (Python 3.14.4)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n research_project ipykernel --update-deps --force-reinstall'
