# %% [markdown]
# # Building a Decision Tree

# %% [markdown]
# The following is an interactive Decision Tree builder

# %%
from IPython.display import HTML

with open("decision_tree_simulator.html", "r", encoding="utf-8") as f:
    html_content = f.read()

HTML(html_content)
