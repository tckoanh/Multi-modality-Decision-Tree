# %% [markdown]
# # A worked example
#
# Below is a worked example of how to build a Decision Tree step by step, using raw data
#
# ---

# %%
from IPython.display import IFrame

IFrame("figures/Example.pdf", width=900, height=600)
