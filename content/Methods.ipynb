# %% [markdown]
# # A worked example
#
# Below is a step-by-step worked example demonstrating how to build a Decision Tree using raw data. The video contains no audio and is intended to be viewed as a presentation slide deck, so feel free to navigate through the slides in any order and revisit sections as needed.
#
# ---

# %%
from IPython.display import Video, display

display(Video("figures/worked_example.mp4", embed=True))
